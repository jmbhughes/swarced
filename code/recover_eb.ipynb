# %%
i = 0
for epicID in r['KIC/EPIC'][0:10]:
    u = pipeline.analyze(pipeline.getQuery(str(epicID),"0"))
    c = pipeline.analyze(pipeline.getEBQuery(str(epicID),"0"))
    arr = [u.response['peaks'][0],c.response['peaks'][0]]
    print(str(epicID) + ": period of " + str(r['period'][i]))
    print("               u    c")
    for y in arr[0]:
        print("{0:>10s} {1:>6.2f} {2:>6.2f}".\
              format(y.rjust(10),arr[0][y], arr[1][y]))
    i+=1

# %%
from __future__ import division, print_function

# %matplotlib inline
# %config InlineBackend.figure_format = "retina"

from matplotlib import rcParams
rcParams["savefig.dpi"] = 100
rcParams["font.size"] = 20
import h5py
import transit
import numpy as np
import matplotlib.pyplot as pl
from matplotlib.ticker import MaxNLocator
import ketu
import urllib2
import sys
from astropy.io import fits
from astropy.io import ascii
#from eliminate_eclipse import *
import pipeline
from eliminate_eclipses import *

# %%
r = ascii.read("/k2_data/c0_EB")

# %%
for epicid in r['KIC/EPIC']:
    pipeline.analyze(pipeline.getQuery(str(epicid),"0"))
    pipeline.analyze(pipeline.getEBQuery(str(epicid),"0"))
# Out:
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.74s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 260.43s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.89s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.19s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 62.00s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.49s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.45s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.91s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.12s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.30s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 62.65s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.33s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.69s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.90s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 66.96s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.35s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.31s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.57s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 75.86s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.60s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.03s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.63s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 74.07s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.06s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.28s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.97s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 43.05s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.19s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.52s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.63s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.54s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.83s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.52s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.33s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 17.65s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.66s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.71s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.44s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.51s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.36s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.31s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.61s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 54.88s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.23s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.85s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.04s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 71.74s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.59s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.09s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.15s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 67.79s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.33s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.77s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.55s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 68.38s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.55s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.18s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.59s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 73.93s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.32s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.31s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.00s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 53.31s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.56s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 54.14s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.55s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 80.58s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.15s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.64s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.05s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 37.63s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.58s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.97s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.13s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.83s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.48s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 49.94s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.65s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 75.75s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.77s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 54.40s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.83s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 83.69s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.80s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.94s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.36s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 75.86s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.96s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.40s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.17s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 82.42s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.81s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 55.11s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.62s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 63.85s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.07s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.78s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.23s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 96.41s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.87s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 43.66s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.85s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 76.40s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.22s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.95s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 260.56s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 69.92s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.19s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.93s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.08s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 78.65s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.53s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.40s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.04s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 76.81s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.82s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.01s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.11s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.19s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.90s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.02s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.38s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 89.19s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.12s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.86s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.74s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 79.99s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.06s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.48s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.14s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 71.20s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.10s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.33s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.48s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 70.13s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.58s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 46.34s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.89s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 68.14s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.42s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.71s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.23s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 81.20s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.80s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.34s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.80s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 96.77s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.29s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.93s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.18s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 107.82s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.55s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.22s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.81s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 84.64s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.60s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.39s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.87s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 74.55s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.94s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.85s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.41s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 71.16s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.55s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 51.17s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.88s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.04s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.86s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 55.84s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.76s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 78.51s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.19s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 39.64s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 261.21s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 66.76s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.52s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 51.79s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.64s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 71.24s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.40s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.02s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.95s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 12.85s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 242.75s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 47.02s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.15s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 78.05s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.77s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.48s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.31s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 88.69s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.91s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.33s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.18s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 80.08s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 249.60s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.77s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257

# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.50s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 54.52s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.74s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 96.49s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.25s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.79s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.38s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 111.14s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.46s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.29s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 260.57s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 126.87s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 254.40s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.73s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.68s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 109.99s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.56s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.08s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.22s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 110.51s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 253.25s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 56.32s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.05s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 87.60s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 253.10s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.87s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.74s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 87.10s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.48s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.23s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.84s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 117.21s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.07s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 55.96s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.32s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 87.20s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.07s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 61.14s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.86s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 63.18s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 247.95s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 59.30s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.64s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 124.17s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.73s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.98s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.94s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 16.02s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 213.88s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 54.91s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 260.07s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 107.00s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.92s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.98s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.33s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 118.20s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.13s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.14s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.54s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 93.84s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.23s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.00s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.57s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 120.01s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.96s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.18s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.27s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 117.39s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 253.30s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.43s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.93s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 105.42s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 250.98s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 58.45s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 258.02s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 111.32s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 252.84s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.51s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 256.87s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 101.96s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.50s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.04s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.13s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 123.53s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.87s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 57.72s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 257.96s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 28.54s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 244.66s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 60.43s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 259.10s
# Using cached value in Likelihood
# Querying OneDSearch
# Finished querying OneDSearch in 118.02s
# Querying IterativeTwoDSearch
# Finished querying IterativeTwoDSearch in 251.08s

# %%
def load(epicid):
    un = pipeline.analyze(pipeline.getQuery(epicid,"0"))
    cl = pipeline.analyze(pipeline.getEBQuery(epicid,"0"))
    return un, cl

# %%
150 * 3  / 60
# Out:
# 7.5

# %%
un, cl = load('202093968')
# Out:
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch

# %%
un.response
# Out:
# {'peaks': [{'depth': 4.530570146321125,
#    'depth_ivar': 684.2074935196249,
#    'duration': 0.10000000000000001,
#    'period': 4.942812493926386,
#    's2n': 118.50775530551154,
#    't0': 1.133461816884676}]}

# %%
r[r['KIC/EPIC'] == 202093968]
# Out:
# <Table masked=False length=1>
#  KIC/EPIC Campaign   period  period error ...  sdepth  pwidth  swidth   sep
#   int32   string40  float64    float64    ... float64 float64 float64 float64
# --------- -------- --------- ------------ ... ------- ------- ------- -------
# 202093968    K2C0  2.4699998    0.0008402 ...  0.0011   0.042   0.125   0.461

# %%
analysis = []
for name in r['KIC/EPIC']:
    u, c = load(str(name))
    u = u.response['peaks'][0]
    analysis.append([str(name),u['depth'], u['depth_ivar'], u['duration'],u['period'],u['s2n'],u['t0']])
    #                 c.response['peaks'][0]['period'],c.response['peaks'][0]['s2n']])
    #analysis.append([str(name),u.response['peaks'][0]['period'],u.response['peaks'][0]['s2n'],\
    #                 c.response['peaks'][0]['period'],c.response['peaks'][0]['s2n']])
# Out:
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch
# Using cached value in IterativeTwoDSearch

# %%
analysis = np.array(analysis,dtype=np.float)

# %%
col = lambda b: "red" if b else "black"

# %%
analysis[:,2] > 15
# Out:
# array([False, False, False, False, False, False,  True, False,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False,  True,  True, False,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True, False,  True,  True,  True, False,  True,  True,
#         True,  True,  True, False,  True], dtype=bool)

# %%
pl.plot(np.linspace(0,20,10),np.linspace(0,20,10), 'k')
pl.scatter(r['period'],analysis[:,4],c= (analysis[:,5]),cmap='winter',lw=0.25)
pl.clim(0,100)
#pl.ylim(0,50)
#pl.xlim(0,50)
#pl.colorbar()
cbar = pl.colorbar()
#cbar.ax.set_yticklabels(fontsize=10)
cbar.set_label('Signal-to-noise', rotation=270,fontsize=15)
pl.xlabel("Kepler EB catalog period [days]",fontsize=15)
pl.ylabel("FM15 recovered period [days]",fontsize=15)
pl.show()

# %%
r['KIC/EPIC'][((analysis[:,4]/r['period']) > 1.8) * ((analysis[:,4]/r['period']) <2.2)]
# Out:
# <Column name='KIC/EPIC' dtype='int32' length=28>
# 202072061
# 202073262
# 202073067
# 202137209
# 202073438
# 202073063
# 202094234
# 202086291
# 202093968
# 202073061
# 202073440
# 202071731
#       ...
# 202072929
# 202072933
# 202066394
# 202092613
# 202060198
# 202071631
# 202088387
# 202071505
# 202059360
# 202126849
# 202126871
# 202068686

# %%
m = analysis[:,5]>15
pl.plot(np.linspace(0,20,10),np.linspace(0,20,10), 'k')
pl.scatter(r['period'][m],analysis[:,4][m],c="lightgreen",label="Significant")
pl.scatter(r['period'][np.logical_not(m)],analysis[:,4][np.logical_not(m)],c="red",label="Not significant")
pl.legend(fontsize=10)
#pl.clim(0,100)
#pl.ylim(0,50)
#pl.xlim(0,50)
#pl.colorbar()
#cbar = pl.colorbar()
#cbar.ax.set_yticklabels(fontsize=10)
cbar.set_label('Signal-to-noise', rotation=270,fontsize=15)
pl.xlabel("Kepler EB catalog period [days]",fontsize=15)
pl.ylabel("FM15 recovered period [days]",fontsize=15)
pl.show()

# %%
pl.plot(np.linspace(0,20,10),np.linspace(0,20,10), 'k')
pl.scatter(r['period'],analysis[:,4],c= (analysis[:,1]/analysis[:,2]),cmap='winter',lw=0)
pl.clim(0,50)
pl.colorbar()
pl.xlabel("Kepler EB catalog expected period [days]")
pl.ylabel("FM15 EB recovered period [days]")
pl.show()

# %%
pl.plot(np.linspace(0,20,10),np.linspace(0,20,10), 'k')
pl.scatter(r['period'],analysis[:,4],c= (analysis[:,3]),cmap='winter',lw=0)
#pl.clim(0,100)
pl.colorbar()
pl.xlabel("Kepler EB catalog expected period [days]")
pl.ylabel("FM15 EB recovered period [days]")
pl.show()

# %%
pl.plot(np.linspace(0,20,10),np.linspace(0,20,10), 'k')
pl.scatter(r['period'],analysis[:,4],c= (analysis[:,6]),cmap='winter',lw=0)
#pl.clim(0,100)
pl.colorbar()
pl.xlabel("Kepler EB catalog expected period [days]")
pl.ylabel("FM15 EB recovered period [days]")
pl.show()

# %%
pl.plot(analysis[:,4]/r['period'],analysis[:,1],'k.')

# %%
# ?pl.hist

# %%
pl.hist(analysis[:,4]/r['period'],np.arange(0,18,0.5)+0.25,color='grey')
pl.xticks(range(0,18),fontsize=10)
pl.yticks(fontsize=10)
pl.ylabel("Counts")
pl.xlabel("Recovered period / catalog period")
pl.show()

# %%
print(len(a),len(b))
# Out:
# 100 101

# %%
pl.plot(a,b[1:], 'k.')
